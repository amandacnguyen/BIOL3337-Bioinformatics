# %% [markdown]
# # February 12, 2025

# %%
# To run Linux commands:

# !ls
# !pwd

# Uncompress .gz file
# !gzip -d <filename>.gz
# !gzip -d GSE269484_Results_WT_VS_Patient.csv.gz  # in-class example
